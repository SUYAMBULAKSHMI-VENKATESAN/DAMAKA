# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/DAMAKA/blob/main/IIT_M_AI_ML_Workshop_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxW
# ...

# %%
#python is loosely type programming

# %%
a=20
b=45.454
c="dhamaka"
d=False
e=5+3j

# %%
type(a), type(b), type(c), type(d), type(e)
# Out:
# (int, float, str, bool, complex)

# %%
a=20
b=45.454
c="dhamaka"
d=False
e=5+3j

# %%
# 'end=" " ' is used to not use the new line

print(a)
print(b, end=" ")
print(c)
print(d, end=" ")
print(e)
# Out:
# 20
# 45.454 dhamaka
# False (5+3j)

# %%
print(a,b,c,d,e) #normally python goes from top to bottom
# Out:
# 20 45.454 dhamaka False (5+3j)

# %%
f = print("good morning") #now python goes left to right
# Out:
# good morning

# %%
print(f)
# Out:
# None

# %%
print(print(print("hello")))
# Out:
# hello
# None
# None

# %%
print("hi", print("bye"), "why")
# Out:
# bye
# hi None why

# %% [markdown]
# "100" + 100

# %%
"100"*10  #give 100 10 times
# Out:
# '100100100100100100100100100100'

# %% [markdown]
# eval("1+2+3") #evaluating this process

# %%
eval("2*3*4*5") #evaluating this expression


#PEMDAS par exp
# Out:
# 120

# %%
#data using data structure

# %% [markdown]
# ## **AI** **PROCESS**
#
#
#
#
# > Indented block
#
# 1.   Get the data or Make a Data
# 2.   Analyse the Date(img, mp4, audio)
# 3.   Cleaning the data
# 4.   Traun the data
# 5.   Test the data
# 6.   Deploy the data
#
# **US Based web services**
#
#
# 1.   mockaroo
# 2.   kaggle
# 3.   uci
# 4.   amazon
# 5.   bing

# %%
#download the dat from the internet using mockaroo(generates random data)

#for getting the data , we need modules
#module name: numpy, pandas {used for data science}

# %%
import numpy
import pandas

# %%
data = pandas.read_csv("/content/MOCK_DATA (1).csv")

# %%
data
# Out:
#        id first_name   last_name                      email       gender  \
# 0       1       Kris     McGrale           kmcgrale0@pen.io   Polygender
# 1       2     Elnora      Nevins        enevins1@sfgate.com       Female
# 2       3  Katherine  Rockingham      krockingham2@about.me  Genderqueer
# 3       4      Gusta      Serman        gserman3@abc.net.au   Non-binary
# 4       5      Monte      Gorner   mgorner4@arstechnica.com         Male
# ..    ...        ...         ...                        ...          ...
# 995   996       Eddy    Carnalan   ecarnalanrn@bandcamp.com       Female
# 996   997   Thomasin    Toseland       ttoselandro@dmoz.org       Female
# 997   998    Gunther      Dyball  gdyballrp@dagondesign.com         Male
# 998   999       Etti      Czapla   eczaplarq@deviantart.com       Female
# 999  1000     Pincus       Youle          pyoulerr@about.me         Male
#
#           ip_address
# 0     124.148.62.233
# 1      48.158.213.65
# 2    149.102.140.229
# ...

# %%
data.gender.value_counts()
# Out:
# Female         473
# Male           434
# Genderqueer     25
# Agender         16
# Non-binary      14
# Polygender      13
# Genderfluid     13
# Bigender        12
# Name: gender, dtype: int64

# %%
friend={"name":["suyambulakshmi", "shakthi", "rohan", "ayesha", "sharinitha", "pirithiba"], "age":[19, 22, 20, 21, 19, 18]}

friend
# Out:
# {'name': ['suyambulakshmi',
#   'shakthi',
#   'rohan',
#   'ayesha',
#   'sharinitha',
#   'pirithiba'],
#  'age': [19, 22, 20, 21, 19, 18]}

# %%
a=pandas.DataFrame(friend)

# %%
a
# Out:
#              name  age
# 0  suyambulakshmi   19
# 1         shakthi   22
# 2           rohan   20
# 3          ayesha   21
# 4      sharinitha   19
# 5       pirithiba   18

# %%
a["CGPA"]=[8.5, 9, 7.5, 9.2, 9.0, 9.4]

# %%
a
# Out:
#              name  age  CGPA
# 0  suyambulakshmi   19   8.5
# 1         shakthi   22   9.0
# 2           rohan   20   7.5
# 3          ayesha   21   9.2
# 4      sharinitha   19   9.0
# 5       pirithiba   18   9.4

# %%
a.to_csv("suyambulakshmi.csv")

# %%
b=pandas.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/pastry.csv")

# %%
b
# Out:
#                Name                                      Origin  \
# 0    Alexandertorte                                      Latvia
# 1           Alfajor                           Argentina Uruguay
# 2          Aloo pie                         Trinidad and Tobago
# 3         Apple pie                              United Kingdom
# 4     Apple strudel                              Central Europe
# ..              ...                                         ...
# 223      Welsh cake                                       Wales
# 224           Xuixo                           Spain (Catalonia)
# 225           Yurla                                       Tibet
# 226   Zeeuwse bolus  Zeeland, Netherlands, (Jewish (Sephardic))
# 227          Zlebia                                North Africa
#
#                                            Description
# 0                   Pastry strips filled with berries.
# 1            Pastry strips filled with dulce de leche.
# ...

# %%
import matplotlib.pyplot as plt

# %%
#dimension should be same
x=[4,7,8,8,1,4]
y=[19,20,21,25,40,50]

# %%
plt.plot(x,y, c="green") #c represents the color
plt.scatter(x,y, c="red", s=300, marker="^") #points that changes the direction or changes occured in the graph
plt.show()

# %% [markdown]
# **IMAGE PROCESSING USING COMPUTER VISION**

# %%
import cv2

# %%
tk=cv2.imread("/content/siddharth_malhothra.jpg")

# %%
type(tk)
# Out:
# numpy.ndarray

# %%
tk
# Out:
# array([[[188, 197, 201],
#         [189, 198, 202],
#         [189, 198, 202],
#         ...,
#         [214, 219, 218],
#         [214, 219, 218],
#         [214, 219, 218]],
#
#        [[194, 203, 207],
#         [194, 203, 207],
#         [194, 203, 207],
#         ...,
#         [214, 219, 218],
#         [214, 219, 218],
#         [214, 219, 218]],
#
#        [[196, 205, 209],
#         [197, 206, 210],
#         [197, 206, 210],
#         ...,
#         [214, 219, 218],
#         [214, 219, 218],
#         [214, 219, 218]],
#
#        ...,
#
#        [[ 23,  88, 109],
#         [ 20,  85, 106],
#         [ 22,  85, 106],
#         ...,
#         [  0,   0,  11],
#         [  2,   1,  17],
#         [  2,   1,  17]],
#
#        [[ 31,  96, 117],
#         [ 27,  92, 113],
#         [ 23,  86, 107],
#         ...,
#         [  3,   2,  18],
#         [  2,   1,  17],
#         [  2,   1,  17]],
#
#        [[ 37, 101, 125],
#         [ 30,  94, 118],
#         [ 24,  86, 110],
# ...

# %%
plt.imshow(tk)

# %%
tk.shape
# Out:
# (637, 850, 3)

# %%
temp=tk

# %%
plt.imshow(temp)
