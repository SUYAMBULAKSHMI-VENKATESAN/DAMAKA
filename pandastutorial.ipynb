# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/DAMAKA/blob/main/pandastutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas - data manipulation - exploratory data - numpy's topmost layer - more than numpy -PYTHON FOR DATA ANALYSIS-

# %%
import pandas as pd # series(single column), dataframe (more than single)- structured form,unstractured form supports

# %%
#series-to manipulate single column

import numpy as np
#create list or array
a=np.array([1,2,3,4,5])
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#series

lst=["technerd","tn witcher","tn kd","fussion"]
pd.Series(lst)
# Out:
# 0      technerd
# 1    tn witcher
# 2         tn kd
# 3       fussion
# dtype: object

# %%
#dataframe
#list comprehension

lst=["technerd","tn witcher","tn kd","fussion"]
df=pd.DataFrame(lst)
print(df)
# Out:
#             0
# 0    technerd
# 1  tn witcher
# 2       tn kd
# 3     fussion

# %%
#creating dictionary
ab = {"students_name":["sharinitha","ayesha","pirathaba","suyambu"],"class":["ece","cse","ai&ds","ai&ml"]}
pd.Series(ab)
# Out:
# students_name    [sharinitha, ayesha, pirathaba, suyambu]
# class                            [ece, cse, ai&ds, ai&ml]
# dtype: object

# %%
#creating dictionary
ab = {"students_name":["sharinitha","ayesha","pirathaba","suyambu"],"class":["ece","cse","ai&ds","ai&ml"]}
pd.DataFrame(ab)
# Out:
#   students_name  class
# 0    sharinitha    ece
# 1        ayesha    cse
# 2     pirathaba  ai&ds
# 3       suyambu  ai&ml

# %%
df2=pd.read_csv("/content/sample_data/california_housing_train.csv")
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
pd.options.display.max_rows #finding the number of rows
#df2=pd.options.display.max_rows=15
# Out:
# 15

# %%
#head-top , tail-bottom

df2.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df2.tail(10)#parameter not passed - default 5 values
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
df2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df2.shape
# Out:
# (17000, 9)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
#statistical analysis

df2.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16995    False
# 16996    False
# 16997    False
# 16998    False
# 16999    False
# Length: 17000, dtype: bool

# %% [markdown]
# df4=pd.read_csv("/content/movies.csv")

# %%
df4=pd.read_csv("/content/movies.csv")
df4
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %% [markdown]
# df4.isnull()

# %%
df4.isnull()
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime  Gross
# 0      False  False  False   False     False  False  False    False   True
# 1      False  False  False   False     False  False  False    False   True
# 2      False  False  False   False     False  False  False    False   True
# 3      False  False  False   False     False  False  False    False   True
# 4      False  False  False    True     False  False   True     True   True
# ...      ...    ...    ...     ...       ...    ...    ...      ...    ...
# 9994   False  False  False    True     False  False   True     True   True
# 9995   False  False  False    True     False  False   True     True   True
# 9996   False  False  False    True     False  False   True     True   True
# 9997   False  False  False    True     False  False   True     True   True
# 9998   False  False  False    True     False  False   True     True   True
#
# [9999 rows x 9 columns]

# %%
df4new=df4["GENRE"].dropna()
df4new
# Out:
# 0           \nAction, Horror, Thriller
# 1       \nAnimation, Action, Adventure
# 2            \nDrama, Horror, Thriller
# 3       \nAnimation, Adventure, Comedy
# 4              \nAction, Crime, Horror
#                            ...
# 9994       \nAdventure, Drama, Fantasy
# 9995    \nAnimation, Action, Adventure
# 9996              \nDocumentary, Sport
# 9997       \nAdventure, Drama, Fantasy
# 9998       \nAdventure, Drama, Fantasy
# Name: GENRE, Length: 9919, dtype: object

# %%
df4['VOTES'] = df4["VOTES"].fillna(0)
df4["VOTES"] = df4["VOTES"].astype('int')
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     9999 non-null   int64
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 703.2+ KB

# %%
df4["VOTES"].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-a645bf55bf3e> in <cell line: 1>()
# ----> 1 df4["VOTES"].astype('int')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df4["VOTES"] = df4["VOTES"].str.replace(",", "")
df4["VOTES"] = df4["VOTES"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-32ba187391de> in <cell line: 2>()
#       1 df4["VOTES"] = df4["VOTES"].str.replace(",", "")
# ----> 2 df4["VOTES"] = df4["VOTES"].astype("int")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...
