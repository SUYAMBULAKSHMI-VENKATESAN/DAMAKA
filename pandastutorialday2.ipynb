# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/DAMAKA/blob/main/pandastutorialday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#day 2 pandas tutorial

import numpy as np
import pandas as pd

df=pd.read_csv("/content/dataset2.csv")
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.columns
# Out:
# Index(['sl No', 'name', 'college', 'hsc', 'SSLC', 'arrears', 'cmark'], dtype='object')

# %%
df.shape #20 rows 7 columns
# Out:
# (20, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sl No    17 non-null     float64
#  1   name     17 non-null     object
#  2   college  15 non-null     object
#  3   hsc      15 non-null     float64
#  4   SSLC     15 non-null     float64
#  5   arrears  16 non-null     float64
#  6   cmark    16 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
df.isnull() #finding null values
# Out:
#     sl No   name  college    hsc   SSLC  arrears  cmark
# 0    True   True     True   True   True     True   True
# 1   False  False    False  False  False    False  False
# 2   False  False    False  False  False    False   True
# 3   False  False    False   True  False    False  False
# 4   False  False    False  False  False    False  False
# 5   False  False     True  False  False    False  False
# 6   False  False    False  False  False    False  False
# 7   False  False    False  False   True    False  False
# 8   False  False    False  False  False    False  False
# 9   False  False    False  False  False    False  False
# 10  False  False    False   True  False    False  False
# 11   True   True     True   True   True     True   True
# 12   True   True     True   True   True     True   True
# 13  False  False    False  False  False    False  False
# 14  False  False    False  False  False     True  False
# 15  False  False    False  False  False    False  False
# ...

# %%
df.isnull().sum() #no of null values
# Out:
# sl No      3
# name       3
# college    5
# hsc        5
# SSLC       5
# arrears    4
# cmark      4
# dtype: int64

# %%
df.isna() #anaother method to find out null values
# Out:
#     sl No   name  college    hsc   SSLC  arrears  cmark
# 0    True   True     True   True   True     True   True
# 1   False  False    False  False  False    False  False
# 2   False  False    False  False  False    False   True
# 3   False  False    False   True  False    False  False
# 4   False  False    False  False  False    False  False
# 5   False  False     True  False  False    False  False
# 6   False  False    False  False  False    False  False
# 7   False  False    False  False   True    False  False
# 8   False  False    False  False  False    False  False
# 9   False  False    False  False  False    False  False
# 10  False  False    False   True  False    False  False
# 11   True   True     True   True   True     True   True
# 12   True   True     True   True   True     True   True
# 13  False  False    False  False  False    False  False
# 14  False  False    False  False  False     True  False
# 15  False  False    False  False  False    False  False
# ...

# %%
df.isna().sum()
# Out:
# sl No      3
# name       3
# college    5
# hsc        5
# SSLC       5
# arrears    4
# cmark      4
# dtype: int64

# %%
new_df=df.dropna()

# %%
df['SSLC']=df.dropna(subset=['SSLC'],inplace=True)
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  None      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  None      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0   76.0
# 5     5.0   A5                  NaN  79.30  None      2.0   89.0
# 6     6.0   A6                  SRM  99.80  None      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  None     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  None      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0   76.0
# 14   10.0   AD               fogjof  56.00  None      NaN    2.0
# 15   11.0  A10                 IITM  94.00  None      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  None      3.0   83.0
# ...

# %%
df.dropna(how="all") #if any row completely contains the null values then it will drop that particular row
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  None      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  None      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0   76.0
# 5     5.0   A5                  NaN  79.30  None      2.0   89.0
# 6     6.0   A6                  SRM  99.80  None      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  None     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  None      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0   76.0
# 14   10.0   AD               fogjof  56.00  None      NaN    2.0
# 15   11.0  A10                 IITM  94.00  None      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  None      3.0   83.0
# ...

# %%
df.dropna(how="any") #if a row contain single null values then it drops the whole row values

# %%
df.reset_index() # to get the missing index values
# Out:
#     index  sl No name              college    hsc  SSLC  arrears  cmark
# 0       1    1.0   A1                 IITM  89.90  None      0.0   95.0
# 1       2    2.0   A2      ANNA UNIVERSITY  76.80  None      3.0    NaN
# 2       3    3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 3       4    4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0   76.0
# 4       5    5.0   A5                  NaN  79.30  None      2.0   89.0
# 5       6    6.0   A6                  SRM  99.80  None      0.0   89.6
# 6       8    8.0   A8             SAVEETHA  99.80  None     66.0   77.5
# 7       9   56.0  A34             SAVEETHA  99.80  None      5.0   77.5
# 8      10    3.0   A3      ANNA UNIVERSITY    NaN  None      6.0   99.0
# 9      13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0   76.0
# 10     14   10.0   AD               fogjof  56.00  None      NaN    2.0
# 11     15   11.0  A10                 IITM  94.00  None      1.0   75.0
# ...

# %%
df.fillna("none")
# Out:
#     sl No name              college    hsc  SSLC arrears cmark
# 1     1.0   A1                 IITM   89.9  none     0.0  95.0
# 2     2.0   A2      ANNA UNIVERSITY   76.8  none     3.0  none
# 3     3.0   A3      ANNA UNIVERSITY   none  none     6.0  99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY   92.5  none     1.0  76.0
# 5     5.0   A5                 none   79.3  none     2.0  89.0
# 6     6.0   A6                  SRM   99.8  none     0.0  89.6
# 8     8.0   A8             SAVEETHA   99.8  none    66.0  77.5
# 9    56.0  A34             SAVEETHA   99.8  none     5.0  77.5
# 10    3.0   A3      ANNA UNIVERSITY   none  none     6.0  99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY   98.7  none     2.0  76.0
# 14   10.0   AD               fogjof   56.0  none    none   2.0
# 15   11.0  A10                 IITM   94.0  none     1.0  75.0
# 17   13.0  A12            dhgvuicbh   78.9  none     3.0  83.0
# 18   14.0  A13                  SRM   86.9  none    33.0  92.0
# ...

# %%
df['hsc'].fillna(0).mean()
# Out:
# 76.05266666666668

# %%
df.describe().T #T means transpose - column values are shown as row values - more convinient
# Out:
#          count       mean        std   min     25%   50%    75%   max
# sl No     15.0   9.866667  13.405045   1.0   3.000   6.0  10.50  56.0
# hsc       13.0  87.753077  12.584976  56.0  79.300  89.9  98.70  99.8
# arrears   14.0   9.571429  18.236541   0.0   1.250   3.0   6.00  66.0
# cmark     14.0  80.685714  24.465167   2.0  76.375  86.0  94.25  99.0

# %%
df.dropna() #forward fill, backward fill - 2 methods
# Out:
# Empty DataFrame
# Columns: [sl No, name, college, hsc, SSLC, arrears, cmark]
# Index: []

# %%
df.fillna(method="ffill") #it copies the previous value of the none value
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  None      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  None      3.0   95.0
# 3     3.0   A3      ANNA UNIVERSITY  76.80  None      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0   76.0
# 5     5.0   A5  ANAMALAI UNIVERSITY  79.30  None      2.0   89.0
# 6     6.0   A6                  SRM  99.80  None      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  None     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  None      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  99.80  None      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0   76.0
# 14   10.0   AD               fogjof  56.00  None      2.0    2.0
# 15   11.0  A10                 IITM  94.00  None      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  None      3.0   83.0
# ...

# %%
df.fillna(method="bfill")
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  None      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  None      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  None      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0   76.0
# 5     5.0   A5                  SRM  79.30  None      2.0   89.0
# 6     6.0   A6                  SRM  99.80  None      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  None     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  None      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  None      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0   76.0
# 14   10.0   AD               fogjof  56.00  None      1.0    2.0
# 15   11.0  A10                 IITM  94.00  None      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  None      3.0   83.0
# ...

# %%
df.rename(columns={'cmark': 'cgpa'}) #rename the column values
# Out:
#     sl No name              college    hsc  SSLC  arrears  cgpa
# 1     1.0   A1                 IITM  89.90  None      0.0  95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  None      3.0   NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  None      6.0  99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  None      1.0  76.0
# 5     5.0   A5                  NaN  79.30  None      2.0  89.0
# 6     6.0   A6                  SRM  99.80  None      0.0  89.6
# 8     8.0   A8             SAVEETHA  99.80  None     66.0  77.5
# 9    56.0  A34             SAVEETHA  99.80  None      5.0  77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  None      6.0  99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  None      2.0  76.0
# 14   10.0   AD               fogjof  56.00  None      NaN   2.0
# 15   11.0  A10                 IITM  94.00  None      1.0  75.0
# 17   13.0  A12            dhgvuicbh  78.90  None      3.0  83.0
# 18   14.0  A13                  SRM  86.90  None     33.0  92.0
# ...

# %%
df.fillna(0).mode() #frequent occurent of the particular value
# Out:
#    sl No name          college   hsc  SSLC  arrears  cmark
# 0    3.0   A3  ANNA UNIVERSITY  99.8   0.0      0.0   99.0
# 1    NaN  NaN              NaN   NaN   NaN      6.0    NaN

# %%
df.dropna(subset=["cmark"],inplace=True)
