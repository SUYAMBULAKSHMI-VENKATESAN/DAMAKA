# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/DAMAKA/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pickle
import string
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import pandas as pd
import numpy as np

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd

# Load data from CSV file into a Pandas DataFrame
file_path = "/content/dialogs.txt"  # Replace 'dialogs.csv' with your file path
data = pd.read_csv(file_path, sep="_", header=None, names=["column"])

# %%
import pandas as pd

# Assuming df is the DataFrame containing your data
# Replace 'conversations' with the column name containing your dialogues
data["column"] = data["column"].str.split('\t').str[0]  # Keeping only the first part of the dialogue

# Drop duplicate rows based on the conversations column
data.drop_duplicates(subset="column", keep='first', inplace=True)

# Display the DataFrame without duplicates
print(data)

data.shape
# Out:
#                                                  column
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
# [3510 rows x 1 columns]
# (3510, 1)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# %%
import string
import nltk
from nltk.corpus import stopwords

# Assuming 'data' is the text you've read from a file
if isinstance(data, str):  # Check if 'data' is already a string
    sentence_tokenize = nltk.sent_tokenize(data)
    word_tokenizer = nltk.word_tokenize(data)

    punct = string.punctuation
    stop_words = set(stopwords.words('english'))  # Retrieve English stopwords

    cleaned_data = []
    for word in word_tokenizer:
        if word not in punct:
            if word not in stop_words:
                cleaned_data.append(word)

    # 'cleaned_data' will contain a list of words after removing punctuation and stopwords
    print(cleaned_data)
else:
    print("'data' is not a string. Please ensure 'data' contains text data in a string format.")


print(type(data))  # Verify the type of data you're working with
print(data)
# Out:
# 'data' is not a string. Please ensure 'data' contains text data in a string format.
# <class 'pandas.core.frame.DataFrame'>
#                                                  column
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
# [3510 rows x 1 columns]

# %%
print(type(data))  # Verify the type of data you're working with
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                  column
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
# [3510 rows x 1 columns]

# %%
import string
import nltk
from nltk.corpus import stopwords

# Assuming 'data' is your DataFrame and the text is in the first column
text_column = data.iloc[:, 0]

# Process the text within the column
cleaned_data = []
for sentence in text_column:
    word_tokenizer = nltk.word_tokenize(sentence)
    punct = string.punctuation
    for word in word_tokenizer:
        if word not in punct:
            if word not in stop_words:
                cleaned_data.append(word)


cleaned_data = str(cleaned_data)
print(cleaned_data)
print(type(cleaned_data))

cleaned_data = str(cleaned_data)
# Out:
# ['hi', "'m", 'fine', "'m", 'pretty', 'good', 'thanks', 'asking', 'problem', "'ve", 'great', "'ve", 'good', "'m", 'school', 'right', 'school', 'go', 'go', 'pcc', 'like', "'s", 'okay', "'s", 'really', 'big', 'campus', 'good', 'luck', 'school', "'s", 'going', "'m", 'well', 'never', 'better', 'thanks', 'lately', "'ve", 'actually', 'pretty', 'good', "'m", 'actually', 'school', 'right', 'school', 'attend', "'m", 'attending', 'pcc', 'right', 'enjoying', "'s", 'bad', 'lot', 'people', 'good', 'luck', 'today', "'m", 'great', "'m", 'absolutely', 'lovely', 'thank', 'everything', "'s", 'good', "n't", 'better', 'started', 'school', 'recently', 'going', 'school', "'m", 'going', 'pcc', 'like', 'far', 'like', 'far', 'classes', 'pretty', 'good', 'right', "'s", 'ugly', 'day', 'today', 'know', 'think', 'may', 'rain', "'s", 'middle', 'summer', "n't", 'rain', 'today', 'would', 'weird', 'yeah', 'especially', 'since', "'s", 'ninety', 'degrees', 'outside', 'know', 'would', 'horrible', 'rained', 'hot', 'outsi
# ...

# %%
input_texts = cleaned_data[::2]  # Extracting odd-indexed sentences
target_texts = cleaned_data[1::2]

print(input_texts)
# Out:
# [h' '" fn' '" pet' go' tak' akn' polm,"v" get,"v" go' '" sho' rgt,'col,'o,'o,'c' lk' '" oa' '" ral' bg,'aps,'od,'uk,'col,"s,'on' '" wl' nvr,'etr,'hns,'aey,"v" atal' pet' go' '" atal' sho' rgt,'col,'ted,"m,'tedn' pc,'ih' ejyn' '" bd,'o' pol' go' lc' tdy,"m,'ra' '" asltl' lvl' tak,'vrtig,"s,'od,"'" bte' satd,'col,'eety,'on' sho' '" gig,'c' lk' fr,'ie,'a' cass,'rty,'od,'ih' '" ul' dy,'oa' ko' tik,'a' ri' '" mdl' sme' nt,'an,'oa' wud,'er' ya' epcal' sne,"s,'iey,'ere' otie,'nw,'ol' hril' rie' ht,'usd' ys,'ol' ral' ws' nt,'o' eey,'a' c' nt,'at,'itr,'ie,'itr,'oeie' gt' cl' '" rte' cl' ht,"'" lo' nc' otie,'oa' 'e,'ih' tik,"s,'on' ri' ltr,'ide,'umr,"'" riig,'ol' nt,'em,'ih' cnieig,"s,'iey,'ere' otie,'ol' wid,'xcl' wud,"'" nc' satd,'ann' '" ht,'nw,"r" asltl' rgt,'ih,'ol' co' oe,'a' '" fe' wn' wne' cm' so' ejy,'itr,'es,'ely,'od,'oeie' ko' ma' '" rte' cl' ht,'ih,'ie' dy,'oa' tu' hp' nt,'an,'ol' nt,'an,'ide,'umr,'ol' nt,'em,'ih' satd,'ann' rgt,'ol' wid,'tre' riig,'iey,'ere,'ete' ri' rgt,'ol' pite
# ...
