# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/DAMAKA/blob/main/pandasday2session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/movies.csv")
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
dfnew=df.rename(columns={"RunTime":"RUNTIME","Gross":"GROSS","ONE-LINE":"ONE_LINE"})
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
dfnew.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE_LINE       0
# STARS          0
# VOTES       1820
# RUNTIME     2958
# GROSS       9539
# dtype: int64

# %%
dfnew.duplicated().sum()
# Out:
# 431

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE_LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RUNTIME   7041 non-null   float64
#  8   GROSS     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
dfnew['VOTES']=dfnew['VOTES'].str.replace(',','')
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['VOTES']=dfnew['VOTES'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['VOTES']=dfnew['VOTES'].astype('int')
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE_LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     9999 non-null   int64
#  7   RUNTIME   7041 non-null   float64
#  8   GROSS     460 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 703.2+ KB

# %%
dfnew['GENRE']=dfnew['GENRE'].str.replace('\n','')
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['GENRE']=dfnew['GENRE'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['ONE_LINE']=dfnew['ONE_LINE'].str.replace('\n','')
dfnew['ONE_LINE']=dfnew['ONE_LINE'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['RATING']=dfnew['RATING'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['STARS']=dfnew['STARS'].str.replace('\n','')
dfnew['STARS']=dfnew['STARS'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['GROSS']=dfnew['GROSS'].fillna(0)
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...

# %%
dfnew['RUNTIME']=dfnew['RUNTIME'].fillna(0)
dfnew['RUNTIME']=dfnew['RUNTIME'].astype('int')
dfnew
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# ...
